# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
engine = create_engine('mysql+pymysql://root:root@127.0.0.1:3306/AICHALLENGE')

# Replace 'your_table' with the actual name of your table
table_name = 'Book'

# %%
query = f'SELECT * FROM {table_name}'

# Query the data into a pandas DataFrame
df = pd.read_sql(query, con=engine)
df = df.head(100)
df
# Out:
#       bookId                                      title  \
# 0     book_1                           The Hunger Games
# 1     book_2  Harry Potter and the Order of the Phoenix
# 2     book_3                      To Kill a Mockingbird
# 3     book_4                        Pride and Prejudice
# 4     book_6                             The Book Thief
# ..       ...                                        ...
# 95   book_97                            Winnie-the-Pooh
# 96   book_98             The Complete Stories and Poems
# 97   book_99                 Interview with the Vampire
# 98  book_100                    A Prayer for Owen Meany
# 99  book_101                    Moby-Dick or, the Whale
#
#                        series  \
# 0         The Hunger Games #1
# 1             Harry Potter #5
# 2       To Kill a Mockingbird
# 3                        None
# 4                        None
# ..                        ...
# 95         Winnie-the-Pooh #1
# 96                       None
# 97  The Vampire Chronicles #1
# 98                       None
# 99                       None
#
#                                                author  rating  \
# 0                                     Suzanne Collins     0.0
# 1           J.K. Rowling, Mary GrandPré (Illustrator)     0.0
# 2                                          Harper Lee     0.0
# 3           Jane Austen, Anna Quindlen (Introduction)     0.0
# 4                     Markus Zusak (Goodreads Author)     0.0
# ..                                                ...     ...
# 95        A.A. Milne, Ernest H. Shepard (Illustrator)     0.0
# 96                                    Edgar Allan Poe     0.0
# 97                                          Anne Rice     0.0
# 98                     John Irving (Goodreads Author)     0.0
# 99  Herman Melville, Andrew Delbanco (Introduction...     0.0
#
#                                           description  pages  \
# 0   WINNING MEANS FAME AND FORTUNE.LOSING MEANS CE...    374
# 1   There is a door at the end of a silent corrido...    870
# 2   The unforgettable novel of a childhood in a sl...    324
# 3   Alternate cover edition of ISBN 9780679783268S...    279
# 4   Librarian's note: An alternate cover edition c...    552
# ..                                                ...    ...
# 95  The adventures of Christopher Robin and his fr...    145
# 96  This single volume brings together all of Poe'...    821
# 97  This is the story of Louis, as told in his own...    342
# 98  Eleven-year-old Owen Meany, playing in a Littl...    637
# 99  "It is the horrible texture of a fabric that s...    654
#
#                            publisher publishDate  \
# 0                   Scholastic Press    09/14/08
# 1                    Scholastic Inc.    09/28/04
# 2   Harper Perennial Modern Classics    05/23/06
# 3                     Modern Library    10/10/00
# 4                    Alfred A. Knopf    03/14/06
# ..                               ...         ...
# 95                   Dutton Juvenile    10/01/01
# 96         Doubleday & Company, Inc.    08/15/84
# 97                  Ballantine Books    08/31/04
# 98                        Black Swan    10/28/90
# 99                  Penguin Classics    02/21/03
#
#                                              coverImg  price  language_2  \
# 0   https://i.gr-assets.com/images/S/compressed.ph...   5.09  portuguese
# 1   https://i.gr-assets.com/images/S/compressed.ph...   7.38       hindi
# 2   https://i.gr-assets.com/images/S/compressed.ph...  10.00     chinese
# 3   https://i.gr-assets.com/images/S/compressed.ph...  10.00     chinese
# 4   https://i.gr-assets.com/images/S/compressed.ph...   3.80     russian
# ..                                                ...    ...         ...
# 95  https://i.gr-assets.com/images/S/compressed.ph...   5.30     spanish
# 96  https://i.gr-assets.com/images/S/compressed.ph...   5.27    japanese
# 97  https://i.gr-assets.com/images/S/compressed.ph...   2.66     russian
# 98  https://i.gr-assets.com/images/S/compressed.ph...   2.86     italian
# 99  https://i.gr-assets.com/images/S/compressed.ph...   1.87     italian
#
#     language_3  language_4  language_5 language_1
# 0       german     russian    japanese    english
# 1   portuguese      arabic      german    english
# 2        hindi      arabic    japanese    english
# 3      bengali    japanese     italian    english
# 4       german     bengali     chinese    english
# ..         ...         ...         ...        ...
# 95     spanish     russian      german    english
# 96       hindi  portuguese      arabic    english
# 97     russian     bengali      german    english
# 98     italian     italian  portuguese    english
# 99     chinese     italian      german    english
#
# [100 rows x 16 columns]

# %%
import pickle
import openai
from embeddings_utils import (
    get_embedding,
    distances_from_embeddings,
    tsne_components_from_embeddings,
    chart_from_components,
    indices_of_nearest_neighbors_from_distances,
)

# constants
EMBEDDING_MODEL = "text-embedding-ada-002"

# %% [markdown]
# # caching

# %%
from openai import OpenAI
from dotenv import load_dotenv
import os

load_dotenv()
api_key=os.getenv("OPENAI_KEY",None)

client = OpenAI(
    # defaults to os.environ.get("OPENAI_API_KEY")
    api_key=api_key,
)

# %%
from typing import List


def get_embedding_local(text: str, engine="text-embedding-ada-002") -> List[float]:

    # replace newlines, which can negatively affect performance.
    text = text.replace("\n", " ")

    res = client.embeddings.create(
        model=engine,
        input=[text],
        encoding_format="float"
    )
    return res.data[0].embedding

# %%
# establish a cache of embeddings to avoid recomputing
# cache is a dict of tuples (text, model) -> embedding, saved as a pickle file

# set path to embedding cache
embedding_cache_path = "data/description_embeddings_cache.pkl"

# load the cache if it exists, and save a copy to disk
try:
    embedding_cache = pd.read_pickle(embedding_cache_path)
except FileNotFoundError:
    embedding_cache = {}
with open(embedding_cache_path, "wb") as embedding_cache_file:
    pickle.dump(embedding_cache, embedding_cache_file)

# define a function to retrieve embeddings from the cache if present, and otherwise request via the API
def embedding_from_string(
    id: str,
    string: str,
    model: str = EMBEDDING_MODEL,
    embedding_cache=embedding_cache
) -> list:
    print((id, model))
    """Return embedding of given string, using a cache to avoid recomputing."""
    if (id, model) not in embedding_cache.keys():
        embedding_cache[(id, model)] = get_embedding_local(string, model)
        with open(embedding_cache_path, "wb") as embedding_cache_file:
            pickle.dump(embedding_cache, embedding_cache_file)
    return (id, embedding_cache[(id, model)])

# %%
def recommendations_from_strings(
   ids: List[str],
   strings: List[str],
   index_of_source_string: str,
   model=EMBEDDING_MODEL,
   k_nearest_neighbors: int = 5,
) -> List[int]:
   """Return nearest neighbors of a given string."""

   # get embeddings for all strings
   embeddings = [embedding_from_string(id, string, model=model) for id, string in zip(ids, strings)]

   # get the embedding of the source string
   query_embedding = embeddings[index_of_source_string]

   # get distances between the source embedding and other embeddings (function from embeddings_utils.py)
   distances = distances_from_embeddings(query_embedding, embeddings, distance_metric="cosine")

   # get indices of nearest neighbors (function from embeddings_utils.py)
   indices_of_nearest_neighbors = indices_of_nearest_neighbors_from_distances(distances)

   # print out source string
   query_string = strings[index_of_source_string]

   # print out its k nearest neighbors
   k_counter = 0

   # list of the first k distances, ordered
   k_distances = []
   for i in indices_of_nearest_neighbors:
      # skip any strings that are identical matches to the starting string
      if query_string != strings[i]:
         
         # stop after printing out k articles
         if k_counter >= k_nearest_neighbors:
            return k_distances
         
         k_counter += 1
         

         # print out the similar strings and their distances
         print(
            f"""
         --- Recommendation #{k_counter}: (nearest neighbor {k_counter} of {k_nearest_neighbors}) ---
         String: {strings[i]}
         Distance: {distances[i]:0.3f}"""
         )

         k_distances.append(i)

condition = df["bookId"]=='book_98'
index_book = df[condition].index.to_list()[0]
recommendations_from_strings(df["bookId"], df["description"], index_book)
# Out:
# ('book_1', 'text-embedding-ada-002')
# ('book_2', 'text-embedding-ada-002')
# ('book_3', 'text-embedding-ada-002')
# ('book_4', 'text-embedding-ada-002')
# ('book_6', 'text-embedding-ada-002')
# ('book_7', 'text-embedding-ada-002')
# ('book_8', 'text-embedding-ada-002')
# ('book_9', 'text-embedding-ada-002')
# ('book_10', 'text-embedding-ada-002')
# ('book_11', 'text-embedding-ada-002')
# ('book_12', 'text-embedding-ada-002')
# ('book_13', 'text-embedding-ada-002')
# ('book_14', 'text-embedding-ada-002')
# ('book_15', 'text-embedding-ada-002')
# ('book_16', 'text-embedding-ada-002')
# ('book_17', 'text-embedding-ada-002')
# ('book_18', 'text-embedding-ada-002')
# ('book_19', 'text-embedding-ada-002')
# ('book_20', 'text-embedding-ada-002')
# ('book_21', 'text-embedding-ada-002')
# ('book_22', 'text-embedding-ada-002')
# ('book_23', 'text-embedding-ada-002')
# ('book_24', 'text-embedding-ada-002')
# ('book_25', 'text-embedding-ada-002')
# ('book_26', 'text-embedding-ada-002')
# ('book_27', 'text-embedding-ada-002')
# ('book_28', 'text-embedding-ada-002')
# ('book_29', 'text-embedding-ada-002')
# ('book_30', 'text-embedding-ada-002')
# ('book_31', 'text-embedding-ada-002')
# ('book_32', 'text-embedding-ada-002')
# ('book_33', 'text-embedding-ada-002')
# ('book_34', 'text-embedding-ada-002')
# ('book_35', 'text-embedding-ada-002')
# ('book_36', 'text-embedding-ada-002')
# ('book_37', 'text-embedding-ada-002')
# ('book_38', 'text-embedding-ada-002')
# ('book_39', 'text-embedding-ada-002')
# ('book_40', 'text-embedding-ada-002')
# ('book_41', 'text-embedding-ada-002')
# ('book_42', 'text-embedding-ada-002')
# ('book_43', 'text-embedding-ada-002')
# ('book_44', 'text-embedding-ada-002')
# ('book_45', 'text-embedding-ada-002')
# ('book_46', 'text-embedding-ada-002')
# ('book_47', 'text-embedding-ada-002')
# ('book_48', 'text-embedding-ada-002')
# ('book_49', 'text-embedding-ada-002')
# ('book_50', 'text-embedding-ada-002')
# ('book_51', 'text-embedding-ada-002')
# ('book_52', 'text-embedding-ada-002')
# ('book_53', 'text-embedding-ada-002')
# ('book_54', 'text-embedding-ada-002')
# ('book_55', 'text-embedding-ada-002')
# ('book_56', 'text-embedding-ada-002')
# ('book_57', 'text-embedding-ada-002')
# ('book_58', 'text-embedding-ada-002')
# ('book_59', 'text-embedding-ada-002')
# ('book_60', 'text-embedding-ada-002')
# ('book_61', 'text-embedding-ada-002')
# ('book_62', 'text-embedding-ada-002')
# ('book_63', 'text-embedding-ada-002')
# ('book_64', 'text-embedding-ada-002')
# ('book_65', 'text-embedding-ada-002')
# ('book_66', 'text-embedding-ada-002')
# ('book_67', 'text-embedding-ada-002')
# ('book_68', 'text-embedding-ada-002')
# ('book_69', 'text-embedding-ada-002')
# ('book_70', 'text-embedding-ada-002')
# ('book_71', 'text-embedding-ada-002')
# ('book_72', 'text-embedding-ada-002')
# ('book_73', 'text-embedding-ada-002')
# ('book_74', 'text-embedding-ada-002')
# ('book_75', 'text-embedding-ada-002')
# ('book_76', 'text-embedding-ada-002')
# ('book_77', 'text-embedding-ada-002')
# ('book_78', 'text-embedding-ada-002')
# ('book_79', 'text-embedding-ada-002')
# ('book_80', 'text-embedding-ada-002')
# ('book_81', 'text-embedding-ada-002')
# ('book_82', 'text-embedding-ada-002')
# ('book_83', 'text-embedding-ada-002')
# ('book_84', 'text-embedding-ada-002')
# ('book_85', 'text-embedding-ada-002')
# ('book_86', 'text-embedding-ada-002')
# ('book_87', 'text-embedding-ada-002')
# ('book_88', 'text-embedding-ada-002')
# ('book_89', 'text-embedding-ada-002')
# ('book_90', 'text-embedding-ada-002')
# ('book_91', 'text-embedding-ada-002')
# ('book_92', 'text-embedding-ada-002')
# ('book_93', 'text-embedding-ada-002')
# ('book_94', 'text-embedding-ada-002')
# ('book_95', 'text-embedding-ada-002')
# ('book_96', 'text-embedding-ada-002')
# ('book_97', 'text-embedding-ada-002')
# ('book_98', 'text-embedding-ada-002')
# ('book_99', 'text-embedding-ada-002')
# ('book_100', 'text-embedding-ada-002')
# ('book_101', 'text-embedding-ada-002')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/luca/Desktop/AICHALLENGE/AiChallenge/test_embeddings.ipynb Cell 9 line 5
#      <a href='vscode-notebook-cell:/home/luca/Desktop/AICHALLENGE/AiChallenge/test_embeddings.ipynb#X15sZmlsZQ%3D%3D?line=50'>51</a> condition = df["bookId"]=='book_98'
#      <a href='vscode-notebook-cell:/home/luca/Desktop/AICHALLENGE/AiChallenge/test_embeddings.ipynb#X15sZmlsZQ%3D%3D?line=51'>52</a> index_book = df[condition].index.to_list()[0]
# ---> <a href='vscode-notebook-cell:/home/luca/Desktop/AICHALLENGE/AiChallenge/test_embeddings.ipynb#X15sZmlsZQ%3D%3D?line=52'>53</a> recommendations_from_strings(df["bookId"], df["description"], index_book)
#
# /home/luca/Desktop/AICHALLENGE/AiChallenge/test_embeddings.ipynb Cell 9 line 1
#      <a href='vscode-notebook-cell:/home/luca/Desktop/AICHALLENGE/AiChallenge/test_embeddings.ipynb#X15sZmlsZQ%3D%3D?line=13'>14</a> query_embedding = embeddings[index_of_source_string]
#      <a href='vscode-notebook-cell:/home/luca/Desktop/AICHALLENGE/AiChallenge/test_embeddings.ipynb#X15sZmlsZQ%3D%3D?line=15'>16</a> # get distances between the source embedding and other embeddings (function from embeddings_utils.py)
# ---> <a href='vscode-notebook-cell:/home/luca/Desktop/AICHALLENGE/AiChallenge/test_embeddings.ipynb#X15sZmlsZQ%3D%3D?line=16'>17</a> distances = distances_from_embeddings(query_embedding, embeddings, distance_metric="cosine")
#      <a href='vscode-notebook-cell:/home/luca/Desktop/AICHALLENGE/AiChallenge/test_embeddings.ipynb#X15sZmlsZQ%3D%3D?line=18'>19</a> # get indices of nearest neighbors (function from embeddings_utils.py)
#      <a href='vscode-notebook-cell:/home/luca/Desktop/AICHALLENGE/AiChallenge/test_embeddings.ipynb#X15sZmlsZQ%3D%3D?line=19'>20</a> indices_of_nearest_neighbors = indices_of_nearest_neighbors_from_distances(distances)
#
# File ~/Desktop/AICHALLENGE/AiChallenge/embeddings_utils.py:147, in distances_from_embeddings(query_embedding, embeddings, distance_metric)
#     140 """Return the distances between a query embedding and a list of embeddings."""
#     141 distance_metrics = {
#     142     "cosine": spatial.distance.cosine,
#     143     "L1": spatial.distance.cityblock,
#     144     "L2": spatial.distance.euclidean,
#     145     "Linf": spatial.distance.chebyshev,
#     146 }
# --> 147 distances = [
#     148     distance_metrics[distance_metric](query_embedding, embedding)
#     149     for embedding in embeddings
#     150 ]
#     151 return distances
#
# File ~/Desktop/AICHALLENGE/AiChallenge/embeddings_utils.py:148, in <listcomp>(.0)
#     140 """Return the distances between a query embedding and a list of embeddings."""
#     141 distance_metrics = {
#     142     "cosine": spatial.distance.cosine,
#     143     "L1": spatial.distance.cityblock,
#     144     "L2": spatial.distance.euclidean,
#     145     "Linf": spatial.distance.chebyshev,
#     146 }
#     147 distances = [
# --> 148     distance_metrics[distance_metric](query_embedding, embedding)
#     149     for embedding in embeddings
#     150 ]
#     151 return distances
#
# File ~/Desktop/AICHALLENGE/AiChallenge/.venv/lib/python3.9/site-packages/scipy/spatial/distance.py:684, in cosine(u, v, w)
#     642 """
#     643 Compute the Cosine distance between 1-D arrays.
#     644
#    (...)
#     679
#     680 """
#     681 # cosine distance is also referred to as 'uncentered correlation',
#     682 #   or 'reflective correlation'
#     683 # clamp the result to 0-2
# --> 684 return max(0, min(correlation(u, v, w=w, centered=False), 2.0))
#
# File ~/Desktop/AICHALLENGE/AiChallenge/.venv/lib/python3.9/site-packages/scipy/spatial/distance.py:624, in correlation(u, v, w, centered)
#     591 def correlation(u, v, w=None, centered=True):
#     592     """
#     593     Compute the correlation distance between two 1-D arrays.
#     594
#    (...)
#     622
#     623     """
# --> 624     u = _validate_vector(u)
#     625     v = _validate_vector(v)
#     626     if w is not None:
#
# File ~/Desktop/AICHALLENGE/AiChallenge/.venv/lib/python3.9/site-packages/scipy/spatial/distance.py:315, in _validate_vector(u, dtype)
#     313 def _validate_vector(u, dtype=None):
#     314     # XXX Is order='c' really necessary?
# --> 315     u = np.asarray(u, dtype=dtype, order='c')
#     316     if u.ndim == 1:
#     317         return u
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (2,) + inhomogeneous part.

# %%
# print out source string
query_string = df["description"][0]
print(f"Source string: {query_string}")
# Out:
# Source string: WINNING MEANS FAME AND FORTUNE.LOSING MEANS CERTAIN DEATH.THE HUNGER GAMES HAVE BEGUN. . . .In the ruins of a place once known as North America lies the nation of Panem, a shining Capitol surrounded by twelve outlying districts. The Capitol is harsh and cruel and keeps the districts in line by forcing them all to send one boy and once girl between the ages of twelve and eighteen to participate in the annual Hunger Games, a fight to the death on live TV.Sixteen-year-old Katniss Everdeen regards it as a death sentence when she steps forward to take her sister's place in the Games. But Katniss has been close to dead before—and survival, for her, is second nature.
